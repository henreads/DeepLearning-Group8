# %% [markdown]
# # Teacher-Student Distillation Notebook
#
# This notebook runs experiment `12` using a teacher-student distillation anomaly detector with a configurable teacher backbone on the shared `64x64` wafer split.
#
# Updated workflow:
# - load the shared teacher-student config
# - inspect the dataset split and CUDA status
# - optionally train the model and save artifacts under `artifacts/`
# - run the default shared evaluation for apples-to-apples comparison
# - optionally launch a same-notebook ablation sweep over teacher layers and `topk_ratio`
# - run a post-training teacher-student score sweep over branch weights and wafer-level reductions
# - compare the default score against stronger rescoring variants in the same notebook

# %%
from pathlib import Path
import json
import subprocess
import sys

from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader

cwd = Path.cwd().resolve()
candidate_roots = [cwd, *cwd.parents]
REPO_ROOT = None
for candidate in candidate_roots:
    if (candidate / "src" / "wafer_defect").exists() and (candidate / "configs").exists():
        REPO_ROOT = candidate
        break

if REPO_ROOT is None:
    raise RuntimeError("Could not locate repo root containing src/wafer_defect and configs/")

SRC_ROOT = REPO_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from wafer_defect.config import load_toml
from wafer_defect.data.wm811k import WaferMapDataset
from wafer_defect.evaluation.reconstruction_metrics import summarize_threshold_metrics, sweep_threshold_metrics
from wafer_defect.models.ts_distillation import build_ts_distillation_from_config
from wafer_defect.scoring import spatial_max, spatial_mean, topk_spatial_mean

# %%
CONFIG_OPTIONS = {
    "resnet18_teacher": REPO_ROOT / "configs" / "training" / "train_ts_resnet18.toml",
    "resnet50_teacher": REPO_ROOT / "configs" / "training" / "train_ts_resnet50.toml",
}
CONFIG_NAME = "resnet18_teacher"
CONFIG_PATH = CONFIG_OPTIONS[CONFIG_NAME]
THRESHOLD_QUANTILE = 0.95
RUN_TRAINING = True
RUN_DEFAULT_EVALUATION = True

RUN_ABLATION_SWEEP = True
ABLATION_PROFILE = "focused"  # "focused" or "full"
if ABLATION_PROFILE == "focused":
    ABLATION_LAYERS = ["layer1", "layer2"]
    ABLATION_TOPK_RATIOS = [0.15, 0.20, 0.25]
    ABLATION_EPOCHS_OVERRIDE = 15
else:
    ABLATION_LAYERS = ["layer1", "layer2", "layer3"]
    ABLATION_TOPK_RATIOS = [0.10, 0.15, 0.20, 0.25, 0.30]
    ABLATION_EPOCHS_OVERRIDE = 20
ABLATION_REUSE_EXISTING = True

SCORE_SWEEP_WEIGHTS = [
    (1.0, 1.0),
    (1.0, 0.0),
    (0.0, 1.0),
    (2.0, 1.0),
    (1.0, 2.0),
    (1.0, 0.5),
    (0.5, 1.0),
]
SCORE_SWEEP_REDUCTIONS = [
    ("mean", None),
    ("max", None),
    ("topk_mean", 0.01),
    ("topk_mean", 0.05),
    ("topk_mean", 0.10),
    ("topk_mean", 0.20),
]

config = load_toml(CONFIG_PATH)
output_dir = REPO_ROOT / config["run"]["output_dir"]
evaluation_dir = output_dir / "evaluation"
evaluation_dir.mkdir(parents=True, exist_ok=True)
best_model_path = output_dir / "best_model.pt"
print(f"Using config: {CONFIG_NAME} -> {CONFIG_PATH.name}")
config
# Out:
# Using config: resnet18_teacher -> train_ts_resnet18.toml
# {'run': {'output_dir': 'artifacts/x64/ts_resnet18', 'seed': 42},
#  'data': {'metadata_csv': 'data/processed/x64/wm811k/metadata_50k_5pct.csv',
#   'image_size': 64,
#   'batch_size': 32,
#   'num_workers': 0},
#  'training': {'epochs': 30,
#   'learning_rate': 0.0003,
#   'weight_decay': 1e-05,
#   'device': 'auto',
#   'early_stopping_patience': 5,
#   'early_stopping_min_delta': 0.0001,
#   'checkpoint_every': 5,
#   'resume_from': ''},
#  'model': {'type': 'ts_distillation',
#   'teacher_backbone': 'resnet18',
#   'teacher_layer': 'layer2',
#   'teacher_pretrained': True,
#   'teacher_input_size': 224,
#   'normalize_teacher_input': True,
#   'feature_autoencoder_hidden_dim': 64,
#   'student_weight': 1.0,
#   'autoencoder_weight': 1.0,
#   'score_student_weight': 1.0,
#   'score_autoencoder_weight': 0.0,
#   'reduction': 'topk_mean',
#   'topk_ratio': 0.2}}

# %%
requested_device = str(config["training"].get("device", "auto"))
if requested_device == "auto":
    resolved_device_name = "cuda" if torch.cuda.is_available() else "cpu"
else:
    resolved_device_name = requested_device

device = torch.device(resolved_device_name)

cuda_summary = {
    "config_device": requested_device,
    "torch_cuda_available": torch.cuda.is_available(),
    "resolved_device": resolved_device_name,
    "cuda_device_count": torch.cuda.device_count(),
}
if torch.cuda.is_available():
    cuda_summary["cuda_device_name"] = torch.cuda.get_device_name(0)

cuda_summary
# Out:
# {'config_device': 'auto',
#  'torch_cuda_available': True,
#  'resolved_device': 'cuda',
#  'cuda_device_count': 1,
#  'cuda_device_name': 'NVIDIA GeForce RTX 3070 Ti Laptop GPU'}

# %%
image_size = int(config["data"].get("image_size", 64))
batch_size = int(config["data"].get("batch_size", 64))
num_workers = int(config["data"].get("num_workers", 0))
metadata_path = REPO_ROOT / config["data"]["metadata_csv"]
metadata = pd.read_csv(metadata_path)

display(metadata.head())
display(metadata.groupby(["split", "is_anomaly"]).size().rename("count").reset_index())

train_dataset = WaferMapDataset(metadata_path, split="train", image_size=image_size)
val_dataset = WaferMapDataset(metadata_path, split="val", image_size=image_size)
test_dataset = WaferMapDataset(metadata_path, split="test", image_size=image_size)

val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

print(f"train={len(train_dataset)}, val={len(val_dataset)}, test={len(test_dataset)}")
# Out:
#                                           array_path label defect_type  \
# 0  data/processed/x64/wm811k/arrays/wafer_0000000...  none        none
# 1  data/processed/x64/wm811k/arrays/wafer_0000001...  none        none
# 2  data/processed/x64/wm811k/arrays/wafer_0000002...  none        none
# 3  data/processed/x64/wm811k/arrays/wafer_0000003...  none        none
# 4  data/processed/x64/wm811k/arrays/wafer_0000004...  none        none
#
#    is_anomaly  split source_split  original_height  original_width
# 0           0  train     Training               25              27
# 1           0  train     Training               55              66
# 2           0  train         Test               33              29
# 3           0  train     Training               25              26
# 4           0  train         Test               39              37
#    split  is_anomaly  count
# 0   test           0   5000
# 1   test           1    250
# 2  train           0  40000
# 3    val           0   5000
# train=40000, val=5000, test=5250

# %%
if RUN_TRAINING:
    train_command = [
        sys.executable,
        "-u",
        str(REPO_ROOT / "scripts" / "train_ts_distillation.py"),
        "--config",
        str(CONFIG_PATH),
    ]
    print("Running:", " ".join(train_command))
    process = subprocess.Popen(
        train_command,
        cwd=REPO_ROOT,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )

    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")

    return_code = process.wait()
    if return_code != 0:
        raise subprocess.CalledProcessError(return_code, train_command)
else:
    print(f"Skipping training. Using existing checkpoint at {best_model_path}")
    if not best_model_path.exists():
        raise FileNotFoundError(f"Checkpoint not found: {best_model_path}. Set RUN_TRAINING = True first.")
# Out:
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\configs\training\train_ts_resnet18.toml
# Epoch 1/30 | train_loss=0.050254 | val_loss=0.033348 | train_distill=0.023304 | val_distill=0.016539 | train_feat_ae=0.026950 | val_feat_ae=0.016808 | best_val=inf
# Epoch 2/30 | train_loss=0.030747 | val_loss=0.029075 | train_distill=0.015184 | val_distill=0.014331 | train_feat_ae=0.015563 | val_feat_ae=0.014745 | best_val=0.033348
# Epoch 3/30 | train_loss=0.028048 | val_loss=0.027540 | train_distill=0.013790 | val_distill=0.013603 | train_feat_ae=0.014258 | val_feat_ae=0.013937 | best_val=0.029075
# Epoch 4/30 | train_loss=0.026779 | val_loss=0.026380 | train_distill=0.013089 | val_distill=0.012857 | train_feat_ae=0.013690 | val_feat_ae=0.013523 | best_val=0.027540
# Epoch 5/30 | train_loss=0.026019 | val_loss=0.025722 | train_distill=0.012678 | val_distill=0.012506 | train_feat_ae=0.013341 | val_feat_ae=0.013216 | best_val=0.026380
# Epoch 6/30 | train_loss=0.025487 | val_loss=0.025443 | train_distill=0.012396 | val_distill=0.012430 | train_feat_ae=0.013091 | val_feat_ae=0.013014 | best_val=0.025722
# Epoch 7/30 | train_loss=0.025112 | val_loss=0.025092 | train_distill=0.012204 | val_distill=0.012226 | train_feat_ae=0.012908 | val_feat_ae=0.012866 | best_val=0.025443
# Epoch 8/30 | train_loss=0.024835 | val_loss=0.024688 | train_distill=0.012062 | val_distill=0.011947 | train_feat_ae=0.012773 | val_feat_ae=0.012740 | best_val=0.025092
# Epoch 9/30 | train_loss=0.024622 | val_loss=0.024548 | train_distill=0.011952 | val_distill=0.011902 | train_feat_ae=0.012669 | val_feat_ae=0.012646 | best_val=0.024688
# Epoch 10/30 | train_loss=0.024442 | val_loss=0.024482 | train_distill=0.011862 | val_distill=0.011924 | train_feat_ae=0.012580 | val_feat_ae=0.012558 | best_val=0.024548
# Epoch 11/30 | train_loss=0.024297 | val_loss=0.024334 | train_distill=0.011793 | val_distill=0.011838 | train_feat_ae=0.012504 | val_feat_ae=0.012496 | best_val=0.024548
# Epoch 12/30 | train_loss=0.024164 | val_loss=0.024196 | train_distill=0.011722 | val_distill=0.011756 | train_feat_ae=0.012442 | val_feat_ae=0.012440 | best_val=0.024334
# Epoch 13/30 | train_loss=0.024069 | val_loss=0.024098 | train_distill=0.011677 | val_distill=0.011707 | train_feat_ae=0.012392 | val_feat_ae=0.012391 | best_val=0.024196
# Epoch 14/30 | train_loss=0.023969 | val_loss=0.023978 | train_distill=0.011620 | val_distill=0.011621 | train_feat_ae=0.012349 | val_feat_ae=0.012357 | best_val=0.024196
# Epoch 15/30 | train_loss=0.023899 | val_loss=0.024002 | train_distill=0.011585 | val_distill=0.011672 | train_feat_ae=0.012314 | val_feat_ae=0.012330 | best_val=0.023978
# Epoch 16/30 | train_loss=0.023823 | val_loss=0.023834 | train_distill=0.011539 | val_distill=0.011547 | train_feat_ae=0.012284 | val_feat_ae=0.012286 | best_val=0.023978
# Epoch 17/30 | train_loss=0.023768 | val_loss=0.023946 | train_distill=0.011512 | val_distill=0.011679 | train_feat_ae=0.012256 | val_feat_ae=0.012267 | best_val=0.023834
# Epoch 18/30 | train_loss=0.023691 | val_loss=0.023780 | train_distill=0.011462 | val_distill=0.011534 | train_feat_ae=0.012229 | val_feat_ae=0.012246 | best_val=0.023834
# Epoch 19/30 | train_loss=0.023650 | val_loss=0.023811 | train_distill=0.011445 | val_distill=0.011598 | train_feat_ae=0.012205 | val_feat_ae=0.012214 | best_val=0.023834
# Epoch 20/30 | train_loss=0.023601 | val_loss=0.023673 | train_distill=0.011417 | val_distill=0.011477 | train_feat_ae=0.012184 | val_feat_ae=0.012196 | best_val=0.023834
# Epoch 21/30 | train_loss=0.023560 | val_loss=0.023576 | train_distill=0.011396 | val_distill=0.011397 | train_feat_ae=0.012164 | val_feat_ae=0.012179 | best_val=0.023673
# Epoch 22/30 | train_loss=0.023518 | val_loss=0.023648 | train_distill=0.011370 | val_distill=0.011482 | train_feat_ae=0.012149 | val_feat_ae=0.012167 | best_val=0.023673
# Epoch 23/30 | train_loss=0.023471 | val_loss=0.023532 | train_distill=0.011338 | val_distill=0.011388 | train_feat_ae=0.012132 | val_feat_ae=0.012144 | best_val=0.023673
# Epoch 24/30 | train_loss=0.023441 | val_loss=0.023542 | train_distill=0.011324 | val_distill=0.011411 | train_feat_ae=0.012117 | val_feat_ae=0.012132 | best_val=0.023532
# Epoch 25/30 | train_loss=0.023408 | val_loss=0.023498 | train_distill=0.011311 | val_distill=0.011385 | train_feat_ae=0.012097 | val_feat_ae=0.012113 | best_val=0.023532
# Epoch 26/30 | train_loss=0.023366 | val_loss=0.023433 | train_distill=0.011282 | val_distill=0.011331 | train_feat_ae=0.012084 | val_feat_ae=0.012101 | best_val=0.023532
# Epoch 27/30 | train_loss=0.023342 | val_loss=0.023353 | train_distill=0.011269 | val_distill=0.011255 | train_feat_ae=0.012073 | val_feat_ae=0.012098 | best_val=0.023532
# Epoch 28/30 | train_loss=0.023322 | val_loss=0.023402 | train_distill=0.011259 | val_distill=0.011318 | train_feat_ae=0.012064 | val_feat_ae=0.012084 | best_val=0.023353
# Epoch 29/30 | train_loss=0.023288 | val_loss=0.023491 | train_distill=0.011233 | val_distill=0.011421 | train_feat_ae=0.012055 | val_feat_ae=0.012070 | best_val=0.023353
# Epoch 30/30 | train_loss=0.023275 | val_loss=0.023421 | train_distill=0.011228 | val_distill=0.011351 | train_feat_ae=0.012047 | val_feat_ae=0.012069 | best_val=0.023353
# Training complete | best_epoch=27 | best_val_loss=0.023353 | student_scale=0.011238 | autoencoder_scale=0.012071

# %%
history_df = pd.read_json(output_dir / "history.json")
training_summary = json.loads((output_dir / "summary.json").read_text(encoding="utf-8"))

display(history_df.tail())
training_summary
# Out:
#     epoch  train_loss  train_distillation_loss  train_autoencoder_loss  \
# 25     26    0.023366                 0.011282                0.012084
# 26     27    0.023342                 0.011269                0.012073
# 27     28    0.023322                 0.011259                0.012064
# 28     29    0.023288                 0.011233                0.012055
# 29     30    0.023275                 0.011228                0.012047
#
#     val_loss  val_distillation_loss  val_autoencoder_loss
# 25  0.023433               0.011331              0.012101
# 26  0.023353               0.011255              0.012098
# 27  0.023402               0.011318              0.012084
# 28  0.023491               0.011421              0.012070
# 29  0.023421               0.011351              0.012069
# {'best_epoch': 27,
#  'best_val_loss': 0.023353473940491677,
#  'epochs_ran': 30,
#  'resumed_from': '',
#  'student_map_scale': 0.01123812533095479,
#  'autoencoder_map_scale': 0.012071360958367586}

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history_df["epoch"], history_df["train_loss"], marker="o", label="train")
axes[0].plot(history_df["epoch"], history_df["val_loss"], marker="o", label="val")
axes[0].set_title("Teacher-Student Total Loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()

axes[1].plot(history_df["epoch"], history_df["train_distillation_loss"], marker="o", label="train distillation")
axes[1].plot(history_df["epoch"], history_df["val_distillation_loss"], marker="o", label="val distillation")
axes[1].plot(history_df["epoch"], history_df["train_autoencoder_loss"], marker="o", linestyle="--", label="train feature AE")
axes[1].plot(history_df["epoch"], history_df["val_autoencoder_loss"], marker="o", linestyle="--", label="val feature AE")
axes[1].set_title("Teacher-Student Branch Losses")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
if RUN_DEFAULT_EVALUATION:
    evaluate_command = [
        sys.executable,
        str(REPO_ROOT / "scripts" / "evaluate_reconstruction_model.py"),
        "--checkpoint",
        str(best_model_path),
        "--config",
        str(CONFIG_PATH),
        "--model-type",
        "ts_distillation",
        "--threshold-quantile",
        str(THRESHOLD_QUANTILE),
        "--output-dir",
        str(evaluation_dir),
    ]
    print("Running:", " ".join(evaluate_command))
    subprocess.run(evaluate_command, cwd=REPO_ROOT, check=True)

default_summary_path = evaluation_dir / "summary.json"
if not default_summary_path.exists():
    raise FileNotFoundError(f"Evaluation summary not found: {default_summary_path}")

default_eval_summary = json.loads(default_summary_path.read_text(encoding="utf-8"))
display(pd.Series(default_eval_summary["metrics_at_validation_threshold"]))
display(pd.Series(default_eval_summary["best_threshold_sweep"]))
# Out:
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\configs\training\train_ts_resnet18.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18\evaluation
# threshold                              2.342451
# precision                                0.4025
# recall                                    0.644
# f1                                     0.495385
# auroc                                  0.894076
# auprc                                  0.519445
# predicted_anomalies                         400
# confusion_matrix       [[4761, 239], [89, 161]]
# dtype: object
# threshold                2.459717
# precision                0.509579
# recall                   0.532000
# f1                       0.520548
# predicted_anomalies    260.000000
# dtype: float64

# %% [markdown]
# ## Optional TS Ablation Sweep
#
# This section can run a compact retraining sweep over teacher feature layers and deployment `topk_ratio` values from the same notebook. The default `focused` preset tests only the highest-value variants first, while `full` restores the broader grid. It writes temporary configs, trains each variant with the standard script, evaluates it with the shared evaluator, and saves a sortable summary table.

# %%
from copy import deepcopy


def format_toml_value(value):
    if isinstance(value, bool):
        return "true" if value else "false"
    if isinstance(value, int) and not isinstance(value, bool):
        return str(value)
    if isinstance(value, float):
        return repr(value)
    return json.dumps(str(value))


def write_simple_toml(path, config_dict):
    lines = []
    for section_name, section_values in config_dict.items():
        lines.append(f"[{section_name}]")
        for key, value in section_values.items():
            lines.append(f"{key} = {format_toml_value(value)}")
        lines.append("")
    path.write_text("\n".join(lines).rstrip() + "\n", encoding="utf-8")


def stream_command(command, cwd):
    print("Running:", " ".join(str(part) for part in command))
    process = subprocess.Popen(
        [str(part) for part in command],
        cwd=cwd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")
    return_code = process.wait()
    if return_code != 0:
        raise subprocess.CalledProcessError(return_code, command)


def build_ablation_variants(base_config, layers, topk_ratios, epochs_override=None):
    variants = []
    backbone_name = str(base_config["model"]["teacher_backbone"]).lower()
    image_size_name = f"x{int(base_config['data'].get('image_size', 64))}"
    for teacher_layer in layers:
        for topk_ratio in topk_ratios:
            variant_config = deepcopy(base_config)
            variant_name = f"ts_{backbone_name}_{teacher_layer}_topk{int(round(topk_ratio * 100)):02d}"
            variant_config["run"]["output_dir"] = f"artifacts/{image_size_name}/{variant_name}"
            variant_config["model"]["teacher_layer"] = teacher_layer
            variant_config["model"]["topk_ratio"] = float(topk_ratio)
            variant_config["model"]["score_student_weight"] = 1.0
            variant_config["model"]["score_autoencoder_weight"] = 0.0
            variant_config["training"]["resume_from"] = ""
            if epochs_override is not None:
                variant_config["training"]["epochs"] = int(epochs_override)
            variants.append({
                "name": variant_name,
                "teacher_layer": teacher_layer,
                "topk_ratio": float(topk_ratio),
                "config": variant_config,
            })
    return variants


def run_ablation_variant(variant, threshold_quantile, reuse_existing):
    variant_name = variant["name"]
    variant_config = variant["config"]
    generated_config_dir = REPO_ROOT / "artifacts" / "generated_configs"
    generated_config_dir.mkdir(parents=True, exist_ok=True)
    config_path = generated_config_dir / f"{variant_name}.toml"
    write_simple_toml(config_path, variant_config)

    variant_output_dir = REPO_ROOT / variant_config["run"]["output_dir"]
    variant_output_dir.mkdir(parents=True, exist_ok=True)
    checkpoint_path = variant_output_dir / "best_model.pt"
    evaluation_output_dir = variant_output_dir / "evaluation"
    evaluation_output_dir.mkdir(parents=True, exist_ok=True)
    summary_path = evaluation_output_dir / "summary.json"

    if reuse_existing and checkpoint_path.exists():
        print(f"Reusing checkpoint for {variant_name}: {checkpoint_path}")
    else:
        stream_command(
            [
                sys.executable,
                "-u",
                REPO_ROOT / "scripts" / "train_ts_distillation.py",
                "--config",
                config_path,
            ],
            cwd=REPO_ROOT,
        )

    if reuse_existing and summary_path.exists():
        print(f"Reusing evaluation for {variant_name}: {summary_path}")
    else:
        stream_command(
            [
                sys.executable,
                REPO_ROOT / "scripts" / "evaluate_reconstruction_model.py",
                "--checkpoint",
                checkpoint_path,
                "--config",
                config_path,
                "--model-type",
                "ts_distillation",
                "--threshold-quantile",
                str(threshold_quantile),
                "--output-dir",
                evaluation_output_dir,
            ],
            cwd=REPO_ROOT,
        )

    train_summary = json.loads((variant_output_dir / "summary.json").read_text(encoding="utf-8"))
    evaluation_summary = json.loads(summary_path.read_text(encoding="utf-8"))
    metrics = evaluation_summary["metrics_at_validation_threshold"]
    best_sweep = evaluation_summary["best_threshold_sweep"]
    return {
        "name": variant_name,
        "teacher_backbone": variant_config["model"]["teacher_backbone"],
        "teacher_layer": variant["teacher_layer"],
        "topk_ratio": variant["topk_ratio"],
        "epochs": int(variant_config["training"]["epochs"]),
        "best_epoch": int(train_summary["best_epoch"]),
        "best_val_loss": float(train_summary["best_val_loss"]),
        "precision": float(metrics["precision"]),
        "recall": float(metrics["recall"]),
        "f1": float(metrics["f1"]),
        "auroc": float(metrics["auroc"]),
        "auprc": float(metrics["auprc"]),
        "best_sweep_f1": float(best_sweep["f1"]),
        "threshold": float(metrics["threshold"]),
        "output_dir": str(variant_output_dir),
        "config_path": str(config_path),
    }


ablation_variants = build_ablation_variants(
    base_config=config,
    layers=ABLATION_LAYERS,
    topk_ratios=ABLATION_TOPK_RATIOS,
    epochs_override=ABLATION_EPOCHS_OVERRIDE,
)

pd.DataFrame(
    [{
        "name": variant["name"],
        "teacher_layer": variant["teacher_layer"],
        "topk_ratio": variant["topk_ratio"],
        "epochs": variant["config"]["training"]["epochs"],
    } for variant in ablation_variants]
)
# Out:
#                         name teacher_layer  topk_ratio  epochs
# 0  ts_resnet18_layer1_topk15        layer1        0.15      15
# 1  ts_resnet18_layer1_topk20        layer1        0.20      15
# 2  ts_resnet18_layer1_topk25        layer1        0.25      15
# 3  ts_resnet18_layer2_topk15        layer2        0.15      15
# 4  ts_resnet18_layer2_topk20        layer2        0.20      15
# 5  ts_resnet18_layer2_topk25        layer2        0.25      15

# %%
ablation_summary_path = evaluation_dir / "ablation_sweep_summary.csv"

if RUN_ABLATION_SWEEP:
    ablation_rows = []
    for variant in ablation_variants:
        print(f"\n=== Ablation: {variant['name']} ===")
        ablation_rows.append(
            run_ablation_variant(
                variant=variant,
                threshold_quantile=THRESHOLD_QUANTILE,
                reuse_existing=ABLATION_REUSE_EXISTING,
            )
        )
    ablation_df = pd.DataFrame(ablation_rows).sort_values(["f1", "auroc"], ascending=False).reset_index(drop=True)
    ablation_df.to_csv(ablation_summary_path, index=False)
    print(f"Saved ablation sweep summary to {ablation_summary_path}")
elif ablation_summary_path.exists():
    ablation_df = pd.read_csv(ablation_summary_path)
    print(f"Loaded existing ablation summary from {ablation_summary_path}")
else:
    ablation_df = pd.DataFrame()
    print("Skipping ablation sweep. Set RUN_ABLATION_SWEEP = True to launch it.")

ablation_df.head(10)
# Out:
# === Ablation: ts_resnet18_layer1_topk15 ===
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer1_topk15.toml
# Epoch 1/15 | train_loss=0.090726 | val_loss=0.052525 | train_distill=0.046181 | val_distill=0.036284 | train_feat_ae=0.044545 | val_feat_ae=0.016241 | best_val=inf
# Epoch 2/15 | train_loss=0.047676 | val_loss=0.044948 | train_distill=0.035067 | val_distill=0.034432 | train_feat_ae=0.012610 | val_feat_ae=0.010516 | best_val=0.052525
# Epoch 3/15 | train_loss=0.043491 | val_loss=0.042693 | train_distill=0.033982 | val_distill=0.033909 | train_feat_ae=0.009508 | val_feat_ae=0.008784 | best_val=0.044948
# Epoch 4/15 | train_loss=0.041781 | val_loss=0.041306 | train_distill=0.033485 | val_distill=0.033384 | train_feat_ae=0.008296 | val_feat_ae=0.007922 | best_val=0.042693
# Epoch 5/15 | train_loss=0.040853 | val_loss=0.040624 | train_distill=0.033206 | val_distill=0.033197 | train_feat_ae=0.007647 | val_feat_ae=0.007427 | best_val=0.041306
# Epoch 6/15 | train_loss=0.040315 | val_loss=0.040190 | train_distill=0.033043 | val_distill=0.033057 | train_feat_ae=0.007271 | val_feat_ae=0.007133 | best_val=0.040624
# Epoch 7/15 | train_loss=0.039943 | val_loss=0.039867 | train_distill=0.032928 | val_distill=0.032943 | train_feat_ae=0.007016 | val_feat_ae=0.006924 | best_val=0.040190
# Epoch 8/15 | train_loss=0.039687 | val_loss=0.039733 | train_distill=0.032851 | val_distill=0.032952 | train_feat_ae=0.006836 | val_feat_ae=0.006781 | best_val=0.039867
# Epoch 9/15 | train_loss=0.039499 | val_loss=0.039589 | train_distill=0.032792 | val_distill=0.032894 | train_feat_ae=0.006707 | val_feat_ae=0.006695 | best_val=0.039733
# Epoch 10/15 | train_loss=0.039343 | val_loss=0.039450 | train_distill=0.032736 | val_distill=0.032812 | train_feat_ae=0.006606 | val_feat_ae=0.006637 | best_val=0.039589
# Epoch 11/15 | train_loss=0.039228 | val_loss=0.039269 | train_distill=0.032701 | val_distill=0.032768 | train_feat_ae=0.006527 | val_feat_ae=0.006501 | best_val=0.039450
# Epoch 12/15 | train_loss=0.039113 | val_loss=0.039226 | train_distill=0.032663 | val_distill=0.032788 | train_feat_ae=0.006450 | val_feat_ae=0.006438 | best_val=0.039269
# Epoch 13/15 | train_loss=0.039017 | val_loss=0.039063 | train_distill=0.032631 | val_distill=0.032693 | train_feat_ae=0.006386 | val_feat_ae=0.006370 | best_val=0.039269
# Epoch 14/15 | train_loss=0.038928 | val_loss=0.039012 | train_distill=0.032609 | val_distill=0.032686 | train_feat_ae=0.006319 | val_feat_ae=0.006326 | best_val=0.039063
# Epoch 15/15 | train_loss=0.038859 | val_loss=0.038928 | train_distill=0.032590 | val_distill=0.032669 | train_feat_ae=0.006269 | val_feat_ae=0.006259 | best_val=0.039063
# Training complete | best_epoch=15 | best_val_loss=0.038928 | student_scale=0.032574 | autoencoder_scale=0.006240
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer1_topk15\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer1_topk15.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer1_topk15\evaluation
# {
#   "model_type": "ts_distillation",
#   "checkpoint": "C:\\Users\\User\\Desktop\\Term 8\\Deep Learning\\Project\\DeepLearning-Group8\\artifacts\\x64\\ts_resnet18_layer1_topk15\\best_model.pt",
#   "threshold_quantile": 0.95,
#   "threshold": 2.9074015974998475,
#   "metrics_at_validation_threshold": {
#     "threshold": 2.9074015974998475,
#     "precision": 0.3421750663129973,
#     "recall": 0.516,
#     "f1": 0.41148325358851673,
#     "auroc": 0.8235812,
#     "auprc": 0.33975563605695785,
#     "predicted_anomalies": 377,
#     "confusion_matrix": [
#       [
#         4752,
#         248
#       ],
#       [
#         121,
#         129
#       ]
#     ]
#   },
#   "best_threshold_sweep": {
#     "threshold": 2.9493651390075684,
#     "precision": 0.41911764705882354,
#     "recall": 0.456,
#     "f1": 0.43678160919490316,
#     "predicted_anomalies": 271
#   },
#   "counts": {
#     "val_normal": 5000,
#     "test_normal": 5000,
#     "test_anomaly": 250
#   }
# }
#
# === Ablation: ts_resnet18_layer1_topk20 ===
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer1_topk20.toml
# Epoch 1/15 | train_loss=0.090727 | val_loss=0.052528 | train_distill=0.046182 | val_distill=0.036287 | train_feat_ae=0.044545 | val_feat_ae=0.016241 | best_val=inf
# Epoch 2/15 | train_loss=0.047674 | val_loss=0.044949 | train_distill=0.035064 | val_distill=0.034432 | train_feat_ae=0.012610 | val_feat_ae=0.010516 | best_val=0.052528
# Epoch 3/15 | train_loss=0.043493 | val_loss=0.042673 | train_distill=0.033985 | val_distill=0.033889 | train_feat_ae=0.009508 | val_feat_ae=0.008784 | best_val=0.044949
# Epoch 4/15 | train_loss=0.041784 | val_loss=0.041305 | train_distill=0.033488 | val_distill=0.033383 | train_feat_ae=0.008296 | val_feat_ae=0.007922 | best_val=0.042673
# Epoch 5/15 | train_loss=0.040856 | val_loss=0.040624 | train_distill=0.033209 | val_distill=0.033197 | train_feat_ae=0.007647 | val_feat_ae=0.007427 | best_val=0.041305
# Epoch 6/15 | train_loss=0.040315 | val_loss=0.040185 | train_distill=0.033044 | val_distill=0.033052 | train_feat_ae=0.007271 | val_feat_ae=0.007133 | best_val=0.040624
# Epoch 7/15 | train_loss=0.039946 | val_loss=0.039853 | train_distill=0.032930 | val_distill=0.032929 | train_feat_ae=0.007016 | val_feat_ae=0.006924 | best_val=0.040185
# Epoch 8/15 | train_loss=0.039687 | val_loss=0.039733 | train_distill=0.032851 | val_distill=0.032952 | train_feat_ae=0.006836 | val_feat_ae=0.006781 | best_val=0.039853
# Epoch 9/15 | train_loss=0.039501 | val_loss=0.039570 | train_distill=0.032794 | val_distill=0.032875 | train_feat_ae=0.006707 | val_feat_ae=0.006695 | best_val=0.039733
# Epoch 10/15 | train_loss=0.039343 | val_loss=0.039468 | train_distill=0.032736 | val_distill=0.032831 | train_feat_ae=0.006606 | val_feat_ae=0.006637 | best_val=0.039570
# Epoch 11/15 | train_loss=0.039229 | val_loss=0.039271 | train_distill=0.032702 | val_distill=0.032770 | train_feat_ae=0.006527 | val_feat_ae=0.006501 | best_val=0.039468
# Epoch 12/15 | train_loss=0.039113 | val_loss=0.039193 | train_distill=0.032663 | val_distill=0.032755 | train_feat_ae=0.006450 | val_feat_ae=0.006438 | best_val=0.039271
# Epoch 13/15 | train_loss=0.039016 | val_loss=0.039043 | train_distill=0.032630 | val_distill=0.032673 | train_feat_ae=0.006386 | val_feat_ae=0.006370 | best_val=0.039271
# Epoch 14/15 | train_loss=0.038927 | val_loss=0.039045 | train_distill=0.032608 | val_distill=0.032719 | train_feat_ae=0.006319 | val_feat_ae=0.006326 | best_val=0.039043
# Epoch 15/15 | train_loss=0.038858 | val_loss=0.038925 | train_distill=0.032589 | val_distill=0.032666 | train_feat_ae=0.006269 | val_feat_ae=0.006259 | best_val=0.039043
# Training complete | best_epoch=15 | best_val_loss=0.038925 | student_scale=0.032571 | autoencoder_scale=0.006240
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer1_topk20\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer1_topk20.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer1_topk20\evaluation
# {
#   "model_type": "ts_distillation",
#   "checkpoint": "C:\\Users\\User\\Desktop\\Term 8\\Deep Learning\\Project\\DeepLearning-Group8\\artifacts\\x64\\ts_resnet18_layer1_topk20\\best_model.pt",
#   "threshold_quantile": 0.95,
#   "threshold": 2.685221803188324,
#   "metrics_at_validation_threshold": {
#     "threshold": 2.685221803188324,
#     "precision": 0.32180851063829785,
#     "recall": 0.484,
#     "f1": 0.3865814696485623,
#     "auroc": 0.8173184,
#     "auprc": 0.3191177947126716,
#     "predicted_anomalies": 376,
#     "confusion_matrix": [
#       [
#         4745,
#         255
#       ],
#       [
#         129,
#         121
#       ]
#     ]
#   },
#   "best_threshold_sweep": {
#     "threshold": 2.710059404373169,
#     "precision": 0.3859060402684564,
#     "recall": 0.46,
#     "f1": 0.4197080291965841,
#     "predicted_anomalies": 297
#   },
#   "counts": {
#     "val_normal": 5000,
#     "test_normal": 5000,
#     "test_anomaly": 250
#   }
# }
#
# === Ablation: ts_resnet18_layer1_topk25 ===
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer1_topk25.toml
# Epoch 1/15 | train_loss=0.090724 | val_loss=0.052537 | train_distill=0.046179 | val_distill=0.036296 | train_feat_ae=0.044545 | val_feat_ae=0.016241 | best_val=inf
# Epoch 2/15 | train_loss=0.047674 | val_loss=0.044966 | train_distill=0.035064 | val_distill=0.034449 | train_feat_ae=0.012610 | val_feat_ae=0.010516 | best_val=0.052537
# Epoch 3/15 | train_loss=0.043487 | val_loss=0.042628 | train_distill=0.033978 | val_distill=0.033844 | train_feat_ae=0.009508 | val_feat_ae=0.008784 | best_val=0.044966
# Epoch 4/15 | train_loss=0.041781 | val_loss=0.041302 | train_distill=0.033485 | val_distill=0.033380 | train_feat_ae=0.008296 | val_feat_ae=0.007922 | best_val=0.042628
# Epoch 5/15 | train_loss=0.040853 | val_loss=0.040619 | train_distill=0.033206 | val_distill=0.033192 | train_feat_ae=0.007647 | val_feat_ae=0.007427 | best_val=0.041302
# Epoch 6/15 | train_loss=0.040315 | val_loss=0.040183 | train_distill=0.033044 | val_distill=0.033051 | train_feat_ae=0.007271 | val_feat_ae=0.007133 | best_val=0.040619
# Epoch 7/15 | train_loss=0.039943 | val_loss=0.039857 | train_distill=0.032927 | val_distill=0.032933 | train_feat_ae=0.007016 | val_feat_ae=0.006924 | best_val=0.040183
# Epoch 8/15 | train_loss=0.039685 | val_loss=0.039749 | train_distill=0.032849 | val_distill=0.032969 | train_feat_ae=0.006836 | val_feat_ae=0.006781 | best_val=0.039857
# Epoch 9/15 | train_loss=0.039498 | val_loss=0.039571 | train_distill=0.032791 | val_distill=0.032876 | train_feat_ae=0.006707 | val_feat_ae=0.006695 | best_val=0.039749
# Epoch 10/15 | train_loss=0.039340 | val_loss=0.039488 | train_distill=0.032734 | val_distill=0.032851 | train_feat_ae=0.006606 | val_feat_ae=0.006637 | best_val=0.039571
# Epoch 11/15 | train_loss=0.039227 | val_loss=0.039270 | train_distill=0.032700 | val_distill=0.032768 | train_feat_ae=0.006527 | val_feat_ae=0.006501 | best_val=0.039571
# Epoch 12/15 | train_loss=0.039112 | val_loss=0.039220 | train_distill=0.032662 | val_distill=0.032782 | train_feat_ae=0.006450 | val_feat_ae=0.006438 | best_val=0.039270
# Epoch 13/15 | train_loss=0.039016 | val_loss=0.039052 | train_distill=0.032629 | val_distill=0.032682 | train_feat_ae=0.006386 | val_feat_ae=0.006370 | best_val=0.039270
# Epoch 14/15 | train_loss=0.038928 | val_loss=0.039030 | train_distill=0.032608 | val_distill=0.032704 | train_feat_ae=0.006319 | val_feat_ae=0.006326 | best_val=0.039052
# Epoch 15/15 | train_loss=0.038858 | val_loss=0.038929 | train_distill=0.032589 | val_distill=0.032671 | train_feat_ae=0.006269 | val_feat_ae=0.006259 | best_val=0.039052
# Training complete | best_epoch=15 | best_val_loss=0.038929 | student_scale=0.032576 | autoencoder_scale=0.006240
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer1_topk25\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer1_topk25.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer1_topk25\evaluation
# {
#   "model_type": "ts_distillation",
#   "checkpoint": "C:\\Users\\User\\Desktop\\Term 8\\Deep Learning\\Project\\DeepLearning-Group8\\artifacts\\x64\\ts_resnet18_layer1_topk25\\best_model.pt",
#   "threshold_quantile": 0.95,
#   "threshold": 2.5203712940216065,
#   "metrics_at_validation_threshold": {
#     "threshold": 2.5203712940216065,
#     "precision": 0.31955922865013775,
#     "recall": 0.464,
#     "f1": 0.37846655791190864,
#     "auroc": 0.8072475999999998,
#     "auprc": 0.2993442146545365,
#     "predicted_anomalies": 363,
#     "confusion_matrix": [
#       [
#         4753,
#         247
#       ],
#       [
#         134,
#         116
#       ]
#     ]
#   },
#   "best_threshold_sweep": {
#     "threshold": 2.5579330921173096,
#     "precision": 0.411522633744856,
#     "recall": 0.4,
#     "f1": 0.40567951318408435,
#     "predicted_anomalies": 242
#   },
#   "counts": {
#     "val_normal": 5000,
#     "test_normal": 5000,
#     "test_anomaly": 250
#   }
# }
#
# === Ablation: ts_resnet18_layer2_topk15 ===
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer2_topk15.toml
# Epoch 1/15 | train_loss=0.050253 | val_loss=0.033326 | train_distill=0.023299 | val_distill=0.016510 | train_feat_ae=0.026955 | val_feat_ae=0.016816 | best_val=inf
# Epoch 2/15 | train_loss=0.030759 | val_loss=0.029288 | train_distill=0.015182 | val_distill=0.014524 | train_feat_ae=0.015577 | val_feat_ae=0.014764 | best_val=0.033326
# Epoch 3/15 | train_loss=0.028078 | val_loss=0.027468 | train_distill=0.013792 | val_distill=0.013506 | train_feat_ae=0.014287 | val_feat_ae=0.013962 | best_val=0.029288
# Epoch 4/15 | train_loss=0.026806 | val_loss=0.026467 | train_distill=0.013095 | val_distill=0.012921 | train_feat_ae=0.013711 | val_feat_ae=0.013546 | best_val=0.027468
# Epoch 5/15 | train_loss=0.026052 | val_loss=0.025747 | train_distill=0.012682 | val_distill=0.012478 | train_feat_ae=0.013370 | val_feat_ae=0.013269 | best_val=0.026467
# Epoch 6/15 | train_loss=0.025544 | val_loss=0.025483 | train_distill=0.012400 | val_distill=0.012402 | train_feat_ae=0.013144 | val_feat_ae=0.013081 | best_val=0.025747
# Epoch 7/15 | train_loss=0.025197 | val_loss=0.025197 | train_distill=0.012216 | val_distill=0.012257 | train_feat_ae=0.012981 | val_feat_ae=0.012941 | best_val=0.025483
# Epoch 8/15 | train_loss=0.024925 | val_loss=0.024821 | train_distill=0.012068 | val_distill=0.011991 | train_feat_ae=0.012857 | val_feat_ae=0.012830 | best_val=0.025197
# Epoch 9/15 | train_loss=0.024726 | val_loss=0.024645 | train_distill=0.011960 | val_distill=0.011895 | train_feat_ae=0.012766 | val_feat_ae=0.012750 | best_val=0.024821
# Epoch 10/15 | train_loss=0.024561 | val_loss=0.024637 | train_distill=0.011869 | val_distill=0.011961 | train_feat_ae=0.012692 | val_feat_ae=0.012676 | best_val=0.024645
# Epoch 11/15 | train_loss=0.024434 | val_loss=0.024492 | train_distill=0.011806 | val_distill=0.011867 | train_feat_ae=0.012628 | val_feat_ae=0.012625 | best_val=0.024645
# Epoch 12/15 | train_loss=0.024311 | val_loss=0.024351 | train_distill=0.011734 | val_distill=0.011768 | train_feat_ae=0.012577 | val_feat_ae=0.012583 | best_val=0.024492
# Epoch 13/15 | train_loss=0.024222 | val_loss=0.024302 | train_distill=0.011688 | val_distill=0.011766 | train_feat_ae=0.012534 | val_feat_ae=0.012536 | best_val=0.024351
# Epoch 14/15 | train_loss=0.024127 | val_loss=0.024317 | train_distill=0.011630 | val_distill=0.011819 | train_feat_ae=0.012496 | val_feat_ae=0.012499 | best_val=0.024351
# Epoch 15/15 | train_loss=0.024054 | val_loss=0.024059 | train_distill=0.011598 | val_distill=0.011592 | train_feat_ae=0.012456 | val_feat_ae=0.012466 | best_val=0.024351
# Training complete | best_epoch=15 | best_val_loss=0.024059 | student_scale=0.011574 | autoencoder_scale=0.012441
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer2_topk15\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer2_topk15.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer2_topk15\evaluation
# {
#   "model_type": "ts_distillation",
#   "checkpoint": "C:\\Users\\User\\Desktop\\Term 8\\Deep Learning\\Project\\DeepLearning-Group8\\artifacts\\x64\\ts_resnet18_layer2_topk15\\best_model.pt",
#   "threshold_quantile": 0.95,
#   "threshold": 2.548744261264801,
#   "metrics_at_validation_threshold": {
#     "threshold": 2.548744261264801,
#     "precision": 0.3925,
#     "recall": 0.628,
#     "f1": 0.48307692307692307,
#     "auroc": 0.8890115999999999,
#     "auprc": 0.5067451230074346,
#     "predicted_anomalies": 400,
#     "confusion_matrix": [
#       [
#         4757,
#         243
#       ],
#       [
#         93,
#         157
#       ]
#     ]
#   },
#   "best_threshold_sweep": {
#     "threshold": 2.625192403793335,
#     "precision": 0.446875,
#     "recall": 0.572,
#     "f1": 0.5017543859644197,
#     "predicted_anomalies": 319
#   },
#   "counts": {
#     "val_normal": 5000,
#     "test_normal": 5000,
#     "test_anomaly": 250
#   }
# }
#
# === Ablation: ts_resnet18_layer2_topk20 ===
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer2_topk20.toml
# Epoch 1/15 | train_loss=0.050256 | val_loss=0.033378 | train_distill=0.023301 | val_distill=0.016561 | train_feat_ae=0.026956 | val_feat_ae=0.016818 | best_val=inf
# Epoch 2/15 | train_loss=0.030745 | val_loss=0.029071 | train_distill=0.015180 | val_distill=0.014321 | train_feat_ae=0.015565 | val_feat_ae=0.014750 | best_val=0.033378
# Epoch 3/15 | train_loss=0.028082 | val_loss=0.027536 | train_distill=0.013798 | val_distill=0.013562 | train_feat_ae=0.014285 | val_feat_ae=0.013974 | best_val=0.029071
# Epoch 4/15 | train_loss=0.026830 | val_loss=0.026510 | train_distill=0.013104 | val_distill=0.012953 | train_feat_ae=0.013727 | val_feat_ae=0.013557 | best_val=0.027536
# Epoch 5/15 | train_loss=0.026059 | val_loss=0.025733 | train_distill=0.012687 | val_distill=0.012493 | train_feat_ae=0.013372 | val_feat_ae=0.013240 | best_val=0.026510
# Epoch 6/15 | train_loss=0.025508 | val_loss=0.025361 | train_distill=0.012405 | val_distill=0.012334 | train_feat_ae=0.013103 | val_feat_ae=0.013027 | best_val=0.025733
# Epoch 7/15 | train_loss=0.025145 | val_loss=0.025116 | train_distill=0.012220 | val_distill=0.012232 | train_feat_ae=0.012925 | val_feat_ae=0.012884 | best_val=0.025361
# Epoch 8/15 | train_loss=0.024871 | val_loss=0.024753 | train_distill=0.012075 | val_distill=0.011984 | train_feat_ae=0.012796 | val_feat_ae=0.012769 | best_val=0.025116
# Epoch 9/15 | train_loss=0.024666 | val_loss=0.024594 | train_distill=0.011964 | val_distill=0.011900 | train_feat_ae=0.012702 | val_feat_ae=0.012694 | best_val=0.024753
# Epoch 10/15 | train_loss=0.024509 | val_loss=0.024520 | train_distill=0.011878 | val_distill=0.011907 | train_feat_ae=0.012631 | val_feat_ae=0.012613 | best_val=0.024594
# Epoch 11/15 | train_loss=0.024378 | val_loss=0.024576 | train_distill=0.011807 | val_distill=0.012008 | train_feat_ae=0.012570 | val_feat_ae=0.012569 | best_val=0.024594
# Epoch 12/15 | train_loss=0.024261 | val_loss=0.024284 | train_distill=0.011741 | val_distill=0.011764 | train_feat_ae=0.012520 | val_feat_ae=0.012520 | best_val=0.024594
# Epoch 13/15 | train_loss=0.024168 | val_loss=0.024157 | train_distill=0.011691 | val_distill=0.011680 | train_feat_ae=0.012477 | val_feat_ae=0.012477 | best_val=0.024284
# Epoch 14/15 | train_loss=0.024074 | val_loss=0.024136 | train_distill=0.011635 | val_distill=0.011685 | train_feat_ae=0.012439 | val_feat_ae=0.012451 | best_val=0.024157
# Epoch 15/15 | train_loss=0.024006 | val_loss=0.023975 | train_distill=0.011602 | val_distill=0.011561 | train_feat_ae=0.012404 | val_feat_ae=0.012414 | best_val=0.024157
# Training complete | best_epoch=15 | best_val_loss=0.023975 | student_scale=0.011543 | autoencoder_scale=0.012389
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer2_topk20\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer2_topk20.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer2_topk20\evaluation
# {
#   "model_type": "ts_distillation",
#   "checkpoint": "C:\\Users\\User\\Desktop\\Term 8\\Deep Learning\\Project\\DeepLearning-Group8\\artifacts\\x64\\ts_resnet18_layer2_topk20\\best_model.pt",
#   "threshold_quantile": 0.95,
#   "threshold": 2.366378486156464,
#   "metrics_at_validation_threshold": {
#     "threshold": 2.366378486156464,
#     "precision": 0.4020100502512563,
#     "recall": 0.64,
#     "f1": 0.49382716049382713,
#     "auroc": 0.8885648,
#     "auprc": 0.5092062924990736,
#     "predicted_anomalies": 398,
#     "confusion_matrix": [
#       [
#         4762,
#         238
#       ],
#       [
#         90,
#         160
#       ]
#     ]
#   },
#   "best_threshold_sweep": {
#     "threshold": 2.458824634552002,
#     "precision": 0.479020979020979,
#     "recall": 0.548,
#     "f1": 0.5111940298502485,
#     "predicted_anomalies": 285
#   },
#   "counts": {
#     "val_normal": 5000,
#     "test_normal": 5000,
#     "test_anomaly": 250
#   }
# }
#
# === Ablation: ts_resnet18_layer2_topk25 ===
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe -u C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\train_ts_distillation.py --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer2_topk25.toml
# Epoch 1/15 | train_loss=0.050250 | val_loss=0.033355 | train_distill=0.023304 | val_distill=0.016540 | train_feat_ae=0.026946 | val_feat_ae=0.016815 | best_val=inf
# Epoch 2/15 | train_loss=0.030728 | val_loss=0.029107 | train_distill=0.015179 | val_distill=0.014374 | train_feat_ae=0.015549 | val_feat_ae=0.014733 | best_val=0.033355
# Epoch 3/15 | train_loss=0.028038 | val_loss=0.027436 | train_distill=0.013800 | val_distill=0.013541 | train_feat_ae=0.014238 | val_feat_ae=0.013895 | best_val=0.029107
# Epoch 4/15 | train_loss=0.026745 | val_loss=0.026376 | train_distill=0.013110 | val_distill=0.012924 | train_feat_ae=0.013635 | val_feat_ae=0.013452 | best_val=0.027436
# Epoch 5/15 | train_loss=0.025962 | val_loss=0.025718 | train_distill=0.012684 | val_distill=0.012554 | train_feat_ae=0.013277 | val_feat_ae=0.013163 | best_val=0.026376
# Epoch 6/15 | train_loss=0.025439 | val_loss=0.025348 | train_distill=0.012399 | val_distill=0.012375 | train_feat_ae=0.013040 | val_feat_ae=0.012973 | best_val=0.025718
# Epoch 7/15 | train_loss=0.025089 | val_loss=0.025024 | train_distill=0.012209 | val_distill=0.012181 | train_feat_ae=0.012879 | val_feat_ae=0.012843 | best_val=0.025348
# Epoch 8/15 | train_loss=0.024847 | val_loss=0.024722 | train_distill=0.012084 | val_distill=0.011987 | train_feat_ae=0.012764 | val_feat_ae=0.012735 | best_val=0.025024
# Epoch 9/15 | train_loss=0.024632 | val_loss=0.024583 | train_distill=0.011959 | val_distill=0.011921 | train_feat_ae=0.012673 | val_feat_ae=0.012662 | best_val=0.024722
# Epoch 10/15 | train_loss=0.024469 | val_loss=0.024478 | train_distill=0.011867 | val_distill=0.011888 | train_feat_ae=0.012602 | val_feat_ae=0.012590 | best_val=0.024583
# Epoch 11/15 | train_loss=0.024345 | val_loss=0.024475 | train_distill=0.011801 | val_distill=0.011934 | train_feat_ae=0.012544 | val_feat_ae=0.012541 | best_val=0.024478
# Epoch 12/15 | train_loss=0.024231 | val_loss=0.024272 | train_distill=0.011733 | val_distill=0.011766 | train_feat_ae=0.012497 | val_feat_ae=0.012505 | best_val=0.024478
# Epoch 13/15 | train_loss=0.024145 | val_loss=0.024131 | train_distill=0.011684 | val_distill=0.011666 | train_feat_ae=0.012461 | val_feat_ae=0.012465 | best_val=0.024272
# Epoch 14/15 | train_loss=0.024059 | val_loss=0.024077 | train_distill=0.011629 | val_distill=0.011642 | train_feat_ae=0.012430 | val_feat_ae=0.012434 | best_val=0.024131
# Epoch 15/15 | train_loss=0.023997 | val_loss=0.024073 | train_distill=0.011594 | val_distill=0.011659 | train_feat_ae=0.012404 | val_feat_ae=0.012414 | best_val=0.024131
# Training complete | best_epoch=13 | best_val_loss=0.024131 | student_scale=0.011647 | autoencoder_scale=0.012439
# Running: c:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\venv\Scripts\python.exe C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\scripts\evaluate_reconstruction_model.py --checkpoint C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer2_topk25\best_model.pt --config C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\generated_configs\ts_resnet18_layer2_topk25.toml --model-type ts_distillation --threshold-quantile 0.95 --output-dir C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18_layer2_topk25\evaluation
# {
#   "model_type": "ts_distillation",
#   "checkpoint": "C:\\Users\\User\\Desktop\\Term 8\\Deep Learning\\Project\\DeepLearning-Group8\\artifacts\\x64\\ts_resnet18_layer2_topk25\\best_model.pt",
#   "threshold_quantile": 0.95,
#   "threshold": 2.214822232723236,
#   "metrics_at_validation_threshold": {
#     "threshold": 2.214822232723236,
#     "precision": 0.40049751243781095,
#     "recall": 0.644,
#     "f1": 0.4938650306748466,
#     "auroc": 0.88974,
#     "auprc": 0.5149875836552942,
#     "predicted_anomalies": 402,
#     "confusion_matrix": [
#       [
#         4759,
#         241
#       ],
#       [
#         89,
#         161
#       ]
#     ]
#   },
#   "best_threshold_sweep": {
#     "threshold": 2.2470498085021973,
#     "precision": 0.4438202247191011,
#     "recall": 0.632,
#     "f1": 0.5214521452140367,
#     "predicted_anomalies": 355
#   },
#   "counts": {
#     "val_normal": 5000,
#     "test_normal": 5000,
#     "test_anomaly": 250
#   }
# }
# Saved ablation sweep summary to C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18\evaluation\ablation_sweep_summary.csv
#                         name teacher_backbone teacher_layer  topk_ratio  \
# 0  ts_resnet18_layer2_topk25         resnet18        layer2        0.25
# 1  ts_resnet18_layer2_topk20         resnet18        layer2        0.20
# 2  ts_resnet18_layer2_topk15         resnet18        layer2        0.15
# 3  ts_resnet18_layer1_topk15         resnet18        layer1        0.15
# 4  ts_resnet18_layer1_topk20         resnet18        layer1        0.20
# 5  ts_resnet18_layer1_topk25         resnet18        layer1        0.25
#
#    epochs  best_epoch  best_val_loss  precision  recall        f1     auroc  \
# 0      15          13       0.024131   0.400498   0.644  0.493865  0.889740
# 1      15          15       0.023975   0.402010   0.640  0.493827  0.888565
# 2      15          15       0.024059   0.392500   0.628  0.483077  0.889012
# 3      15          15       0.038928   0.342175   0.516  0.411483  0.823581
# 4      15          15       0.038925   0.321809   0.484  0.386581  0.817318
# 5      15          15       0.038929   0.319559   0.464  0.378467  0.807248
#
#       auprc  best_sweep_f1  threshold  \
# 0  0.514988       0.521452   2.214822
# 1  0.509206       0.511194   2.366378
# 2  0.506745       0.501754   2.548744
# 3  0.339756       0.436782   2.907402
# 4  0.319118       0.419708   2.685222
# 5  0.299344       0.405680   2.520371
#
#                                           output_dir  \
# 0  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 1  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 2  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 3  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 4  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 5  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
#
#                                          config_path
# 0  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 1  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 2  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 3  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 4  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 5  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...

# %%
if ablation_df.empty:
    print("No ablation sweep results available yet.")
else:
    display(ablation_df)

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    top_rows = ablation_df.head(8)

    axes[0].bar(top_rows["name"], top_rows["f1"], color="#2a9d8f")
    axes[0].set_title("Top Ablations by F1")
    axes[0].set_ylabel("F1")
    axes[0].tick_params(axis="x", rotation=45)

    axes[1].bar(top_rows["name"], top_rows["auroc"], color="#457b9d")
    axes[1].set_title("Top Ablations by AUROC")
    axes[1].set_ylabel("AUROC")
    axes[1].tick_params(axis="x", rotation=45)

    plt.tight_layout()
    plt.show()
# Out:
#                         name teacher_backbone teacher_layer  topk_ratio  \
# 0  ts_resnet18_layer2_topk25         resnet18        layer2        0.25
# 1  ts_resnet18_layer2_topk20         resnet18        layer2        0.20
# 2  ts_resnet18_layer2_topk15         resnet18        layer2        0.15
# 3  ts_resnet18_layer1_topk15         resnet18        layer1        0.15
# 4  ts_resnet18_layer1_topk20         resnet18        layer1        0.20
# 5  ts_resnet18_layer1_topk25         resnet18        layer1        0.25
#
#    epochs  best_epoch  best_val_loss  precision  recall        f1     auroc  \
# 0      15          13       0.024131   0.400498   0.644  0.493865  0.889740
# 1      15          15       0.023975   0.402010   0.640  0.493827  0.888565
# 2      15          15       0.024059   0.392500   0.628  0.483077  0.889012
# 3      15          15       0.038928   0.342175   0.516  0.411483  0.823581
# 4      15          15       0.038925   0.321809   0.484  0.386581  0.817318
# 5      15          15       0.038929   0.319559   0.464  0.378467  0.807248
#
#       auprc  best_sweep_f1  threshold  \
# 0  0.514988       0.521452   2.214822
# 1  0.509206       0.511194   2.366378
# 2  0.506745       0.501754   2.548744
# 3  0.339756       0.436782   2.907402
# 4  0.319118       0.419708   2.685222
# 5  0.299344       0.405680   2.520371
#
#                                           output_dir  \
# 0  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 1  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 2  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 3  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 4  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 5  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
#
#                                          config_path
# 0  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 1  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 2  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 3  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 4  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...
# 5  C:\Users\User\Desktop\Term 8\Deep Learning\Pro...

# %% [markdown]
# ## Teacher-Student Score Sweep
#
# The first teacher-student result looked more like a calibration problem than a training-collapse problem. This sweep keeps the trained checkpoint fixed and tests whether different branch weights and wafer-level reductions produce a stronger operating point under the same validation-threshold rule.

# %%
checkpoint = torch.load(best_model_path, map_location="cpu")
score_sweep_model = build_ts_distillation_from_config(config, image_size=image_size)
score_sweep_model.load_state_dict(checkpoint["model_state_dict"])
score_sweep_model.to(device)
score_sweep_model.eval()

def collect_normalized_maps(model, dataloader, device):
    student_maps = []
    auto_maps = []
    labels = []
    with torch.inference_mode():
        for inputs, batch_labels in dataloader:
            inputs = inputs.to(device)
            student_map, auto_map = model.raw_anomaly_maps(inputs)
            student_maps.append((student_map / model.student_map_scale.clamp_min(1e-6)).cpu())
            auto_maps.append((auto_map / model.autoencoder_map_scale.clamp_min(1e-6)).cpu())
            labels.append(batch_labels.cpu())
    return torch.cat(student_maps, dim=0), torch.cat(auto_maps, dim=0), torch.cat(labels, dim=0).numpy()

val_student_maps, val_auto_maps, val_labels = collect_normalized_maps(score_sweep_model, val_loader, device)
test_student_maps, test_auto_maps, test_labels = collect_normalized_maps(score_sweep_model, test_loader, device)

print(tuple(val_student_maps.shape), tuple(test_student_maps.shape))
# Out:
# (5000, 1, 28, 28) (5250, 1, 28, 28)

# %%
def reduce_anomaly_map(anomaly_map, reduction, topk_ratio):
    if reduction == "mean":
        return spatial_mean(anomaly_map)
    if reduction == "max":
        return spatial_max(anomaly_map)
    return topk_spatial_mean(anomaly_map, topk_ratio=topk_ratio)

score_sweep_rows = []
for student_weight, auto_weight in SCORE_SWEEP_WEIGHTS:
    val_map = student_weight * val_student_maps + auto_weight * val_auto_maps
    test_map = student_weight * test_student_maps + auto_weight * test_auto_maps
    for reduction, topk_ratio in SCORE_SWEEP_REDUCTIONS:
        val_scores = reduce_anomaly_map(val_map, reduction, topk_ratio).numpy()
        test_scores = reduce_anomaly_map(test_map, reduction, topk_ratio).numpy()

        threshold = float(pd.Series(val_scores[val_labels == 0]).quantile(THRESHOLD_QUANTILE))
        metrics = summarize_threshold_metrics(test_labels, test_scores, threshold)
        _, best_sweep = sweep_threshold_metrics(test_labels, test_scores)

        score_sweep_rows.append(
            {
                "name": f"s{student_weight:g}_a{auto_weight:g}_{reduction}" + ("" if topk_ratio is None else f"_r{topk_ratio:.2f}"),
                "student_weight": student_weight,
                "auto_weight": auto_weight,
                "reduction": reduction,
                "topk_ratio": np.nan if topk_ratio is None else topk_ratio,
                "threshold": threshold,
                "precision": metrics["precision"],
                "recall": metrics["recall"],
                "f1": metrics["f1"],
                "auroc": metrics["auroc"],
                "auprc": metrics["auprc"],
                "predicted_anomalies": metrics["predicted_anomalies"],
                "best_sweep_f1": best_sweep["f1"],
            }
        )

score_sweep_df = pd.DataFrame(score_sweep_rows).sort_values(["f1", "auprc", "auroc"], ascending=False).reset_index(drop=True)
score_sweep_path = evaluation_dir / "score_sweep_summary.csv"
score_sweep_df.to_csv(score_sweep_path, index=False)

display(score_sweep_df.head(15))
print(f"Saved score sweep summary to {score_sweep_path}")
# Out:
#                        name  student_weight  auto_weight  reduction  \
# 0     s1_a0_topk_mean_r0.20             1.0          0.0  topk_mean
# 1     s1_a0_topk_mean_r0.10             1.0          0.0  topk_mean
# 2     s2_a1_topk_mean_r0.20             2.0          1.0  topk_mean
# 3   s1_a0.5_topk_mean_r0.20             1.0          0.5  topk_mean
# 4     s1_a1_topk_mean_r0.20             1.0          1.0  topk_mean
# 5     s1_a2_topk_mean_r0.20             1.0          2.0  topk_mean
# 6   s0.5_a1_topk_mean_r0.20             0.5          1.0  topk_mean
# 7     s0_a1_topk_mean_r0.20             0.0          1.0  topk_mean
# 8     s1_a1_topk_mean_r0.10             1.0          1.0  topk_mean
# 9     s2_a1_topk_mean_r0.10             2.0          1.0  topk_mean
# 10  s1_a0.5_topk_mean_r0.10             1.0          0.5  topk_mean
# 11    s1_a0_topk_mean_r0.05             1.0          0.0  topk_mean
# 12    s1_a2_topk_mean_r0.10             1.0          2.0  topk_mean
# 13  s0.5_a1_topk_mean_r0.10             0.5          1.0  topk_mean
# 14               s1_a0_mean             1.0          0.0       mean
#
#     topk_ratio  threshold  precision  recall        f1     auroc     auprc  \
# 0         0.20   2.342452   0.402500   0.644  0.495385  0.894076  0.519445
# 1         0.10   2.795972   0.402597   0.620  0.488189  0.890692  0.496916
# 2         0.20   7.350615   0.387909   0.616  0.476043  0.893469  0.453071
# 3         0.20   3.675308   0.387909   0.616  0.476043  0.893469  0.453071
# 4         0.20   5.065271   0.378446   0.604  0.465331  0.891553  0.406017
# 5         0.20   7.897568   0.379135   0.596  0.463453  0.888585  0.359451
# 6         0.20   3.948784   0.379135   0.596  0.463453  0.888585  0.359451
# 7         0.20   2.848809   0.369347   0.588  0.453704  0.881428  0.291531
# 8         0.10   5.976559   0.363184   0.584  0.447853  0.894078  0.359263
# 9         0.10   8.694245   0.364796   0.572  0.445483  0.894971  0.410821
# 10        0.10   4.347122   0.364796   0.572  0.445483  0.894971  0.410821
# 11        0.05   3.267841   0.371585   0.544  0.441558  0.880274  0.461202
# 12        0.10   9.346237   0.358586   0.568  0.439628  0.892114  0.311154
# 13        0.10   4.673118   0.358586   0.568  0.439628  0.892114  0.311154
# 14         NaN   1.212168   0.347619   0.584  0.435821  0.860190  0.446076
#
#     predicted_anomalies  best_sweep_f1
# 0                   400       0.520548
# 1                   385       0.493023
# 2                   397       0.487141
# 3                   397       0.487141
# 4                   399       0.476879
# 5                   393       0.467719
# 6                   393       0.467719
# 7                   398       0.456395
# 8                   402       0.465181
# 9                   392       0.468705
# 10                  392       0.468705
# 11                  366       0.445183
# 12                  396       0.455696
# 13                  396       0.455696
# 14                  420       0.496920
# Saved score sweep summary to C:\Users\User\Desktop\Term 8\Deep Learning\Project\DeepLearning-Group8\artifacts\x64\ts_resnet18\evaluation\score_sweep_summary.csv

# %%
default_row = pd.DataFrame(
    [
        {
            "name": "default_config_score",
            "precision": default_eval_summary["metrics_at_validation_threshold"]["precision"],
            "recall": default_eval_summary["metrics_at_validation_threshold"]["recall"],
            "f1": default_eval_summary["metrics_at_validation_threshold"]["f1"],
            "auroc": default_eval_summary["metrics_at_validation_threshold"]["auroc"],
            "auprc": default_eval_summary["metrics_at_validation_threshold"]["auprc"],
            "best_sweep_f1": default_eval_summary["best_threshold_sweep"]["f1"],
        }
    ]
)

selected_row = score_sweep_df.iloc[0].copy()
selected_row_df = pd.DataFrame([selected_row])
comparison_df = pd.concat([default_row, selected_row_df[["name", "precision", "recall", "f1", "auroc", "auprc", "best_sweep_f1"]]], ignore_index=True)
display(comparison_df)

selected_variant_summary = selected_row.to_dict()
selected_variant_summary_path = evaluation_dir / "selected_score_variant.json"
selected_variant_summary_path.write_text(json.dumps(selected_variant_summary, indent=2), encoding="utf-8")
selected_variant_summary
# Out:
#                     name  precision  recall        f1     auroc     auprc  \
# 0   default_config_score     0.4025   0.644  0.495385  0.894076  0.519445
# 1  s1_a0_topk_mean_r0.20     0.4025   0.644  0.495385  0.894076  0.519445
#
#    best_sweep_f1
# 0       0.520548
# 1       0.520548
# {'name': 's1_a0_topk_mean_r0.20',
#  'student_weight': 1.0,
#  'auto_weight': 0.0,
#  'reduction': 'topk_mean',
#  'topk_ratio': 0.2,
#  'threshold': 2.342451548576355,
#  'precision': 0.4025,
#  'recall': 0.644,
#  'f1': 0.49538461538461537,
#  'auroc': 0.8940759999999999,
#  'auprc': 0.5194451346662112,
#  'predicted_anomalies': 400,
#  'best_sweep_f1': 0.5205479452049797}

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

repo_root = REPO_ROOT if "REPO_ROOT" in globals() else Path.cwd()
if "evaluation_dir" in globals():
    local_evaluation_dir = Path(evaluation_dir)
else:
    candidate_dirs = [
        repo_root / "artifacts" / "x64" / "ts_resnet18" / "evaluation",
        repo_root / "artifacts" / "x64" / "ts_resnet18" / "evaluation",
    ]
    existing_dirs = [path for path in candidate_dirs if path.exists()]
    if not existing_dirs:
        raise FileNotFoundError("Could not find a TS-Res18 evaluation directory.")
    local_evaluation_dir = existing_dirs[0]

default_summary_path = local_evaluation_dir / "summary.json"
selected_variant_path = local_evaluation_dir / "selected_score_variant.json"
if not default_summary_path.exists():
    raise FileNotFoundError(f"Evaluation summary not found: {default_summary_path}")
if not selected_variant_path.exists():
    raise FileNotFoundError(f"Selected score variant not found: {selected_variant_path}")

default_eval_summary = json.loads(default_summary_path.read_text(encoding="utf-8"))
selected_variant = json.loads(selected_variant_path.read_text(encoding="utf-8"))

default_row = pd.DataFrame(
    [
        {
            "name": "default_config_score",
            "precision": default_eval_summary["metrics_at_validation_threshold"]["precision"],
            "recall": default_eval_summary["metrics_at_validation_threshold"]["recall"],
            "f1": default_eval_summary["metrics_at_validation_threshold"]["f1"],
            "auroc": default_eval_summary["metrics_at_validation_threshold"]["auroc"],
            "auprc": default_eval_summary["metrics_at_validation_threshold"]["auprc"],
            "best_sweep_f1": default_eval_summary["best_threshold_sweep"]["f1"],
        }
    ]
)
selected_row_df = pd.DataFrame([selected_variant])
comparison_df = pd.concat(
    [
        default_row,
        selected_row_df[["name", "precision", "recall", "f1", "auroc", "auprc", "best_sweep_f1"]],
    ],
    ignore_index=True,
)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].bar(["default", "best sweep variant"], comparison_df["f1"], color=["#8d99ae", "#2a9d8f"])
axes[0].set_title("Validation-Threshold F1")
axes[0].set_ylabel("F1")

axes[1].bar(["default", "best sweep variant"], comparison_df["auroc"], color=["#8d99ae", "#2a9d8f"])
axes[1].set_title("AUROC")
axes[1].set_ylabel("AUROC")

plt.tight_layout()
plt.show()
